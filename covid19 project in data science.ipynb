# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing data
df = pd.read_csv("https://raw.githubusercontent.com/imdevskp/covid-19-india-data/master/nation_level_daily.csv")

# %%
df
# Out:
#              Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0     30 January                 1                1                0
# 1     31 January                 0                1                0
# 2    01 February                 0                1                0
# 3    02 February                 1                2                0
# 4    03 February                 1                3                0
# ..            ...              ...              ...              ...
# 185    02 August             52672          1804857            40355
# 186    03 August             50488          1855345            43070
# 187    04 August             51282          1906627            51220
# 188    05 August             56626          1963253            45583
# 189    06 August             62170          2025423            50141
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# ...

# %%
df.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %% [markdown]
#      Here we are importing the first 5-indexes data of covid-19

# %%
df.tail()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 185  02 August             52672          1804857            40355
# 186  03 August             50488          1855345            43070
# 187  04 August             51282          1906627            51220
# 188  05 August             56626          1963253            45583
# 189  06 August             62170          2025423            50141
#
#      Total Recovered  Daily Deceased  Total Deceased
# 185          1187261             760           38180
# 186          1230331             806           38986
# 187          1281551             849           39835
# 188          1327134             919           40754
# 189          1377275             899           41653

# %% [markdown]
#      Here we are importing the last 5 indexes data of covid-19

# %%
df.sample(10)
# Out:
#              Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 178      26 July             48932          1436020            31512
# 133      11 June             11135           298293             6044
# 59      29 March               120             1139               17
# 187    04 August             51282          1906627            51220
# 5    04 February                 0                3                0
# 66      05 April               609             4293               43
# 169      17 July             34820          1040462            17476
# 0     30 January                 1                1                0
# 70      09 April               813             6728               70
# 17   16 February                 0                3                1
#
#      Total Recovered  Daily Deceased  Total Deceased
# 178           918636             704           32827
# 133           146972             394            8501
# ...

# %% [markdown]
#         sample keyword will give the random data from the given data

# %%
df.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %% [markdown]
#        Here we know that how many number of columns are there in the covid-19 data.The number of columns are 7 in data.

# %%
df.shape
# Out:
# (190, 7)

# %% [markdown]
#     The shape is an attribute which will be used to know the number of rows and columns in the data.The number of rows are 190 and columns are 7 in the covid-19 data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             190 non-null    object
#  1   Daily Confirmed  190 non-null    int64
#  2   Total Confirmed  190 non-null    int64
#  3   Daily Recovered  190 non-null    int64
#  4   Total Recovered  190 non-null    int64
#  5   Daily Deceased   190 non-null    int64
#  6   Total Deceased   190 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 10.5+ KB

# %% [markdown]
#       The info keyword is used to know the information of the dataframe

# %%
df.describe()
# Out:
#        Daily Confirmed  Total Confirmed  Daily Recovered  Total Recovered  \
# count       190.000000     1.900000e+02       190.000000     1.900000e+02
# mean      10660.121053     3.088709e+05      7248.815789     1.869665e+05
# std       15739.372014     4.939299e+05     11755.421065     3.223640e+05
# min           0.000000     1.000000e+00         0.000000     0.000000e+00
# 25%          22.750000     1.522500e+02         1.000000     1.500000e+01
# 50%        2961.500000     4.460600e+04      1022.000000     1.230400e+04
# 75%       14512.250000     4.077742e+05     10594.750000     2.246905e+05
# max       62170.000000     2.025423e+06     51368.000000     1.377275e+06
#
#        Daily Deceased  Total Deceased
# count      190.000000      190.000000
# mean       219.226316     7849.294737
# std        291.382213    11371.176250
# min          0.000000        0.000000
# 25%          0.250000        3.000000
# 50%         91.500000     1514.500000
# ...

# %% [markdown]
#       describing about the dataframe like how many number of people are suffered from the covid-19 disease and recovered from the covid-19

# %%
df["Total Recovered"]
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#         ...
# 185    1187261
# 186    1230331
# 187    1281551
# 188    1327134
# 189    1377275
# Name: Total Recovered, Length: 190, dtype: int64

# %% [markdown]
#       This is a series object from the data.The total-recovered people from the covid-19.

# %%
sns.relplot(x="Daily Confirmed",y="Total Confirmed",data=df)

# %% [markdown]
#     relplot is used to show the relationship between two variables with semantic mappings of subsets.Here we are showing the relation between the two objects.

# %%
sns.relplot(x="Total Confirmed",y="Total Recovered",data=df)

# %% [markdown]
#          Here we are showing relation between the Total-confirmed and Total-recovered people from the covid-19 dataframe

# %%
sns.pairplot(df)

# %% [markdown]
#     Pairplot is used to show the pairwise relationships in a dataset.

# %%
df
# Out:
#              Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0     30 January                 1                1                0
# 1     31 January                 0                1                0
# 2    01 February                 0                1                0
# 3    02 February                 1                2                0
# 4    03 February                 1                3                0
# ..            ...              ...              ...              ...
# 185    02 August             52672          1804857            40355
# 186    03 August             50488          1855345            43070
# 187    04 August             51282          1906627            51220
# 188    05 August             56626          1963253            45583
# 189    06 August             62170          2025423            50141
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
sns.catplot(x="Date",y="Total Confirmed",data=df)

# %% [markdown]
#     catplot in seaborn is used to show the relationship between a numerical and one or more categorical variables using one of several visual representations.Here we are showing the relation between the date and total confirmed.

# %%
df.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
sns.rugplot(x=df['Total Recovered'])
# Out:
# <AxesSubplot:xlabel='Total Recovered'>

# %% [markdown]
#          A rug Plot is a type of plot of data for a single quantitative variable, displayed as marks along an axis. It is used to visualise the distribution of the data.By using the rugplot we are showing the total number of recovered people from the covid-19.

# %%
sns.barplot(x=df["Daily Confirmed"],y=df["Total Confirmed"])
# Out:
# <AxesSubplot:xlabel='Daily Confirmed', ylabel='Total Confirmed'>

# %% [markdown]
#     barplot is used to visualise relation between daily confirmed and Total confirmed.

# %%
sns.violinplot(y=df["Total Confirmed"],x=df["Total Recovered"])
# Out:
# <AxesSubplot:xlabel='Total Recovered', ylabel='Total Confirmed'>

# %% [markdown]
#     A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.The above plot is used to show comparison of Total confirmed and total recovered

# %%
sns.stripplot(x=df["Total Confirmed"],y=df["Total Recovered"])
# Out:
# <AxesSubplot:xlabel='Total Confirmed', ylabel='Total Recovered'>

# %% [markdown]
#     The stripplot is show or visualize the total confirmed and total recovered.

# %%
df.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
sns.stripplot(x=df["Daily Deceased"],y=df["Total Deceased"])
# Out:
# <AxesSubplot:xlabel='Daily Deceased', ylabel='Total Deceased'>

# %% [markdown]
#     The relation between the daily deseased and total deceased
